# %%
import pandas as pd
data = pd.read_csv('/Users/willfitzhugh/Desktop/Coding/Supply-Chain-Analysis/Data/Raw Data/DataCoSupplyChainDataset.csv', encoding_errors='ignore')

# %%
data.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# 1                   1           73  Sporting Goods        Caguas  ...
# 2                   0           73  Sporting Goods      San Jose  ...
# 3                   0           73  Sporting Goods   Los Angeles  ...
# 4                   0           73  Sporting Goods        Caguas  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN            1360                  73                  NaN
# 1           NaN            1360                  73                  NaN
# 2           NaN            1360                  73                  NaN
# 3           NaN            1360                  73                  NaN
# 4           NaN            1360                  73                  NaN
#
#                                   Product Image  Product Name Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#   Product Status shipping date (DateOrders)   Shipping Mode
# 0              0             2/3/2018 22:56  Standard Class
# 1              0            1/18/2018 12:27  Standard Class
# 2              0            1/17/2018 12:06  Standard Class
# 3              0            1/16/2018 11:45  Standard Class
# 4              0            1/15/2018 11:24  Standard Class
#
# [5 rows x 53 columns]

# %%
#create single column for customer name
data['CustomerName'] = data['Customer Fname'] + data['Customer Lname'].fillna('')

# %%
#useless columns to drop
useless_cols = ['Product Description','Product Image','Customer Email','Customer Password','Customer Street',
                'Customer Zipcode','Order Zipcode','Order Item Id','Department Id','Product Category Id',
                'Product Card Id','Customer Fname','Customer Lname','Product Status']

#duplicate columns to drop
dup_cols = ['Order Profit Per Order','Order Item Total','Order Item Product Price','Sales','Order Customer Id',
           'Order Item Cardprod Id','Category Id']
    
data = data.drop( columns = dup_cols + useless_cols )

# %%
#rename poorly titled columns
data = data.rename(columns = {'Benefit per order':'OrderProfit','Sales per customer':'OrderSales',
                       'Category Name':'ProductCategory','Department Name':'ProductDepartment',
                       'order date (DateOrders)':'OrderDate','shipping date (DateOrders)':'ShipDate',
                       'ProductInStock':'Product Status','Days for shipping (real)':'RealShippingDays',
                        'Days for shipment (scheduled)':'ScheduledShippingDays'})

# %%
#change date data types
data.OrderDate = pd.to_datetime(data.OrderDate, infer_datetime_format=True)
data.ShipDate = pd.to_datetime(data.ShipDate, infer_datetime_format=True)

# %% [markdown]
# ---

# %%
data.head()
# Out:
#        Type  RealShippingDays  ScheduledShippingDays  OrderProfit  OrderSales  \
# 0     DEBIT                 3                      4    91.250000  314.640015
# 1  TRANSFER                 5                      4  -249.089996  311.359985
# 2      CASH                 4                      4  -247.779999  309.720001
# 3     DEBIT                 3                      4    22.860001  304.809998
# 4   PAYMENT                 2                      4   134.210007  298.250000
#
#     Delivery Status  Late_delivery_risk ProductCategory Customer City  \
# 0  Advance shipping                   0  Sporting Goods        Caguas
# 1     Late delivery                   1  Sporting Goods        Caguas
# 2  Shipping on time                   0  Sporting Goods      San Jose
# 3  Advance shipping                   0  Sporting Goods   Los Angeles
# 4  Advance shipping                   0  Sporting Goods        Caguas
#
#   Customer Country  ...  Order Item Discount Rate Order Item Profit Ratio  \
# 0      Puerto Rico  ...                      0.04                    0.29
# 1      Puerto Rico  ...                      0.05                   -0.80
# 2          EE. UU.  ...                      0.06                   -0.80
# 3          EE. UU.  ...                      0.07                    0.08
# 4      Puerto Rico  ...                      0.09                    0.45
#
#   Order Item Quantity    Order Region      Order State     Order Status  \
# 0                   1  Southeast Asia  Java Occidental         COMPLETE
# 1                   1      South Asia          Rajastn          PENDING
# 2                   1      South Asia          Rajastn           CLOSED
# 3                   1         Oceania       Queensland         COMPLETE
# 4                   1         Oceania       Queensland  PENDING_PAYMENT
#
#    Product Name Product Price            ShipDate   Shipping Mode
# 0  Smart watch         327.75 2018-02-03 22:56:00  Standard Class
# 1  Smart watch         327.75 2018-01-18 12:27:00  Standard Class
# 2  Smart watch         327.75 2018-01-17 12:06:00  Standard Class
# 3  Smart watch         327.75 2018-01-16 11:45:00  Standard Class
# 4  Smart watch         327.75 2018-01-15 11:24:00  Standard Class
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Type                      180519 non-null  object
#  1   RealShippingDays          180519 non-null  int64
#  2   ScheduledShippingDays     180519 non-null  int64
#  3   OrderProfit               180519 non-null  float64
#  4   OrderSales                180519 non-null  float64
#  5   Delivery Status           180519 non-null  object
#  6   Late_delivery_risk        180519 non-null  int64
#  7   ProductCategory           180519 non-null  object
#  8   Customer City             180519 non-null  object
#  9   Customer Country          180519 non-null  object
#  10  Customer Id               180519 non-null  int64
#  11  Customer Segment          180519 non-null  object
#  12  Customer State            180519 non-null  object
#  13  ProductDepartment         180519 non-null  object
#  14  Latitude                  180519 non-null  float64
#  15  Longitude                 180519 non-null  float64
#  16  Market                    180519 non-null  object
#  17  Order City                180519 non-null  object
#  18  Order Country             180519 non-null  object
#  19  OrderDate                 180519 non-null  datetime64[ns]
#  20  Order Id                  180519 non-null  int64
#  21  Order Item Discount       180519 non-null  float64
#  22  Order Item Discount Rate  180519 non-null  float64
#  23  Order Item Profit Ratio   180519 non-null  float64
#  24  Order Item Quantity       180519 non-null  int64
#  25  Order Region              180519 non-null  object
#  26  Order State               180519 non-null  object
#  27  Order Status              180519 non-null  object
#  28  Product Name              180519 non-null  object
#  29  Product Price             180519 non-null  float64
#  30  ShipDate                  180519 non-null  datetime64[ns]
#  31  Shipping Mode             180519 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(6), object(16)
# memory usage: 44.1+ MB

# %%
data.describe()
# Out:
#        RealShippingDays  ScheduledShippingDays    OrderProfit     OrderSales  \
# count     180519.000000          180519.000000  180519.000000  180519.000000
# mean           3.497654               2.931847      21.974989     183.107609
# std            1.623722               1.374449     104.433526     120.043670
# min            0.000000               0.000000   -4274.979980       7.490000
# 25%            2.000000               2.000000       7.000000     104.379997
# 50%            3.000000               4.000000      31.520000     163.990005
# 75%            5.000000               4.000000      64.800003     247.399994
# max            6.000000               4.000000     911.799988    1939.989990
#
#        Late_delivery_risk    Customer Id       Latitude      Longitude  \
# count       180519.000000  180519.000000  180519.000000  180519.000000
# mean             0.548291    6691.379495      29.719955     -84.915675
# std              0.497664    4162.918106       9.813646      21.433241
# min              0.000000       1.000000     -33.937553    -158.025986
# 25%              0.000000    3258.500000      18.265432     -98.446312
# 50%              1.000000    6457.000000      33.144863     -76.847908
# 75%              1.000000    9779.000000      39.279617     -66.370583
# max              1.000000   20757.000000      48.781933     115.263077
#
#             Order Id  Order Item Discount  Order Item Discount Rate  \
# count  180519.000000        180519.000000             180519.000000
# mean    36221.894903            20.664741                  0.101668
# std     21045.379569            21.800901                  0.070415
# min         1.000000             0.000000                  0.000000
# 25%     18057.000000             5.400000                  0.040000
# 50%     36140.000000            14.000000                  0.100000
# 75%     54144.000000            29.990000                  0.160000
# max     77204.000000           500.000000                  0.250000
#
#        Order Item Profit Ratio  Order Item Quantity  Product Price
# count            180519.000000        180519.000000  180519.000000
# mean                  0.120647             2.127638     141.232550
# std                   0.466796             1.453451     139.732492
# min                  -2.750000             1.000000       9.990000
# 25%                   0.080000             1.000000      50.000000
# 50%                   0.270000             1.000000      59.990002
# 75%                   0.360000             3.000000     199.990005
# max                   0.500000             5.000000    1999.989990

# %%
plot_df = data.groupby('Market').sum()[['OrderProfit']].reset_index()
plot_df.plot.bar(x='Market', y='OrderProfit')
# Out:
# <AxesSubplot:xlabel='Market'>

# %%
plot_df = data.groupby('ProductDepartment').sum()[['OrderProfit']].reset_index()
plot_df.plot.bar(x='ProductDepartment', y='OrderProfit')
# Out:
# <AxesSubplot:xlabel='ProductDepartment'>

# %%
data.hist('OrderProfit')
# Out:
# array([[<AxesSubplot:title={'center':'OrderProfit'}>]], dtype=object)

# %%
data['Order Status'].unique()
data[ data['Order Status'] == 'SUSPECTED_FRAUD']
data.query(' Type == "TRANSFER" ')
#data.query(' "Order Status" == "SUSPECTED_FRAUD" ')
# Out:
#             Type  RealShippingDays  ScheduledShippingDays  OrderProfit  \
# 1       TRANSFER                 5                      4  -249.089996
# 5       TRANSFER                 6                      4    18.580000
# 7       TRANSFER                 2                      1    68.430000
# 10      TRANSFER                 6                      2   130.580002
# 11      TRANSFER                 5                      2    45.689999
# ...          ...               ...                    ...          ...
# 180485  TRANSFER                 4                      4    11.160000
# 180487  TRANSFER                 3                      4    27.000000
# 180490  TRANSFER                 4                      4   -59.840000
# 180491  TRANSFER                 3                      4    33.599998
# 180516  TRANSFER                 5                      4   141.110001
#
#         OrderSales    Delivery Status  Late_delivery_risk ProductCategory  \
# 1       311.359985      Late delivery                   1  Sporting Goods
# 5       294.980011  Shipping canceled                   0  Sporting Goods
# 7       285.140015      Late delivery                   1  Sporting Goods
# 10      272.029999  Shipping canceled                   0  Sporting Goods
# 11      268.760010      Late delivery                   1  Sporting Goods
# ...            ...                ...                 ...             ...
# 180485  371.980011   Shipping on time                   0         Fishing
# 180487  359.980011   Advance shipping                   0         Fishing
# 180490  339.980011  Shipping canceled                   0         Fishing
# 180491  335.980011   Advance shipping                   0         Fishing
# 180516  391.980011      Late delivery                   1         Fishing
#
#           Customer City Customer Country  ...  Order Item Discount Rate  \
# 1                Caguas      Puerto Rico  ...                      0.05
# 5             Tonawanda          EE. UU.  ...                      0.10
# 7                 Miami          EE. UU.  ...                      0.13
# 10               Caguas      Puerto Rico  ...                      0.17
# 11             Freeport          EE. UU.  ...                      0.18
# ...                 ...              ...  ...                       ...
# 180485        San Pablo          EE. UU.  ...                      0.07
# 180487  Rowland Heights          EE. UU.  ...                      0.10
# 180490           Madera          EE. UU.  ...                      0.15
# 180491           Caguas      Puerto Rico  ...                      0.16
# 180516          Bristol          EE. UU.  ...                      0.02
#
#        Order Item Profit Ratio Order Item Quantity    Order Region  \
# 1                        -0.80                   1      South Asia
# 5                         0.06                   1         Oceania
# 7                         0.24                   1    Eastern Asia
# 10                        0.48                   1    Eastern Asia
# 11                        0.17                   1  Southeast Asia
# ...                        ...                 ...             ...
# 180485                    0.03                   1    Eastern Asia
# 180487                    0.08                   1      South Asia
# 180490                   -0.18                   1      South Asia
# 180491                    0.10                   1         Oceania
# 180516                    0.36                   1         Oceania
#
#                  Order State     Order Status  \
# 1                    Rajastn          PENDING
# 5                 Queensland         CANCELED
# 7                  Guangdong       PROCESSING
# 10                     Tokio  SUSPECTED_FRAUD
# 11      Clebes Septentrional          PENDING
# ...                      ...              ...
# 180485        Xinjiang Uygur          PENDING
# 180487             Telangana       PROCESSING
# 180490        Madhya Pradesh  SUSPECTED_FRAUD
# 180491              Victoria          PENDING
# 180516     Australia del Sur          PENDING
#
#                                      Product Name Product Price  \
# 1                                    Smart watch     327.750000
# 5                                    Smart watch     327.750000
# 7                                    Smart watch     327.750000
# 10                                   Smart watch     327.750000
# 11                                   Smart watch     327.750000
# ...                                           ...           ...
# 180485  Field & Stream Sportsman 16 Gun Fire Safe    399.980011
# 180487  Field & Stream Sportsman 16 Gun Fire Safe    399.980011
# 180490  Field & Stream Sportsman 16 Gun Fire Safe    399.980011
# 180491  Field & Stream Sportsman 16 Gun Fire Safe    399.980011
# 180516  Field & Stream Sportsman 16 Gun Fire Safe    399.980011
#
#                   ShipDate   Shipping Mode
# 1      2018-01-18 12:27:00  Standard Class
# 5      2018-01-19 11:03:00  Standard Class
# 7      2018-01-15 10:21:00     First Class
# 10     2018-01-19 09:18:00    Second Class
# 11     2018-01-18 08:57:00    Second Class
# ...                    ...             ...
# 180485 2016-01-21 14:42:00  Standard Class
# 180487 2016-01-20 12:36:00  Standard Class
# 180490 2016-01-21 05:56:00  Standard Class
# 180491 2016-01-20 05:35:00  Standard Class
# 180516 2016-01-20 21:00:00  Standard Class
#
# [49883 rows x 32 columns]
